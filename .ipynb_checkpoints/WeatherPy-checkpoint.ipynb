# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities 
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 634

# %% [markdown]
# ## Perform API Calls

# %%
#store API key
api_key = api_keys.api_key

#create lists to be populated by API responses
city_id = []
city_namez = []
temp = []
humidity = []
cloudiness = []
wind_speed = []
latitude = []
longitude = []
date = []
max_temp = []
country = []

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key + "&q="

#loop through random cities and if the city is in the weather API database, append the lists with responses
for city in cities:
    try:
        response = requests.get(url + city).json()
        city_id.append(response["id"])
        city_namez.append(response["name"])
        temp.append(response["main"]["temp"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        country.append(response["sys"]["country"])
        max_temp.append(response["main"]["temp_max"])
        date.append(response["dt"])
        print(f"The city: {city}, city id: {city_id[-1]}, is being processed")
        
    except KeyError:
        print(f"Oops, {city} is not in the API database!")
# Out:
# The city: fukue, city id: 1848373, is being processed
# The city: yilan, city id: 1674199, is being processed
# The city: ribeira grande, city id: 3372707, is being processed
# The city: lucapa, city id: 145724, is being processed
# The city: hastings, city id: 2190224, is being processed
# The city: dikson, city id: 1507390, is being processed
# The city: yerofey pavlovich, city id: 2012938, is being processed
# The city: yarmouth, city id: 2633414, is being processed
# The city: byron bay, city id: 2172880, is being processed
# The city: the valley, city id: 3573374, is being processed
# The city: bubaque, city id: 2374583, is being processed
# The city: ushuaia, city id: 3833367, is being processed
# The city: new norfolk, city id: 2155415, is being processed
# Oops, duz is not in the API database!
# The city: banda aceh, city id: 1215502, is being processed
# The city: nanortalik, city id: 3421765, is being processed
# The city: cape town, city id: 3369157, is being processed
# The city: blythe, city id: 5329649, is being processed
# The city: opuwo, city id: 3354077, is being processed
# The city: north battleford, city id: 6089404, is being processed
# The city: marienburg, city id: 2803461, is being processed
# The city: perth, city id: 2640358, is being processed
# The city: hilo, city id: 5855927, is being processed
# Oops, illoqqortoormiut is not in the API database!
# The city: kawalu, city id: 1640902, is being processed
# The city: salinopolis, city id: 3389822, is being processed
# Oops, samusu is not in the API database!
# The city: mataura, city id: 6201424, is being processed
# The city: leningradskiy, city id: 2123814, is being processed
# The city: ilulissat, city id: 3423146, is being processed
# The city: coihaique, city id: 3894426, is being processed
# The city: warkworth, city id: 2179639, is being processed
# The city: hithadhoo, city id: 1282256, is being processed
# The city: saint-philippe, city id: 6138908, is being processed
# Oops, grand river south east is not in the API database!
# The city: tuktoyaktuk, city id: 6170031, is being processed
# The city: namibe, city id: 3347019, is being processed
# The city: rikitea, city id: 4030556, is being processed
# The city: lamu, city id: 1623890, is being processed
# The city: araouane, city id: 2460954, is being processed
# The city: port alfred, city id: 964432, is being processed
# The city: cidreira, city id: 3466165, is being processed
# The city: punta arenas, city id: 3874787, is being processed
# The city: hermanus, city id: 3366880, is being processed
# The city: skibbereen, city id: 2961459, is being processed
# The city: formosa, city id: 3433899, is being processed
# The city: beloha, city id: 1067565, is being processed
# The city: civitavecchia, city id: 3178587, is being processed
# The city: sao filipe, city id: 3374210, is being processed
# The city: pitimbu, city id: 3391889, is being processed
# The city: busselton, city id: 2075265, is being processed
# The city: yellowknife, city id: 6185377, is being processed
# The city: chern, city id: 569116, is being processed
# Oops, cockburn harbour is not in the API database!
# The city: churapcha, city id: 2025241, is being processed
# The city: nikolskoye, city id: 546105, is being processed
# The city: chuy, city id: 3443061, is being processed
# The city: vanimo, city id: 2084442, is being processed
# The city: simojovel, city id: 3516651, is being processed
# The city: altay, city id: 1529651, is being processed
# The city: puerto ayora, city id: 3652764, is being processed
# The city: vila velha, city id: 6320062, is being processed
# The city: micheweni, city id: 153955, is being processed
# The city: hobart, city id: 2163355, is being processed
# The city: thompson, city id: 6165406, is being processed
# The city: atuona, city id: 4020109, is being processed
# Oops, taolanaro is not in the API database!
# The city: butaritari, city id: 2110227, is being processed
# The city: torbay, city id: 6167817, is being processed
# The city: salalah, city id: 286621, is being processed
# The city: luderitz, city id: 3355672, is being processed
# The city: harnai, city id: 1177098, is being processed
# The city: tessalit, city id: 2449893, is being processed
# Oops, karakendzha is not in the API database!
# The city: nabire, city id: 1634614, is being processed
# Oops, amderma is not in the API database!
# The city: albany, city id: 5106834, is being processed
# The city: ondjiva, city id: 3346821, is being processed
# The city: souillac, city id: 3026644, is being processed
# The city: hatillo, city id: 4565346, is being processed
# The city: segou, city id: 2252081, is being processed
# The city: chumikan, city id: 2025256, is being processed
# The city: carnarvon, city id: 1014034, is being processed
# The city: charters towers, city id: 2171722, is being processed
# Oops, marcona is not in the API database!
# The city: erdenet, city id: 2031405, is being processed
# The city: philadelphia, city id: 4560349, is being processed
# Oops, samalaeulu is not in the API database!
# The city: bredasdorp, city id: 1015776, is being processed
# Oops, halalo is not in the API database!
# The city: alice springs, city id: 2077895, is being processed
# Oops, nguiu is not in the API database!
# The city: aguilas, city id: 2522333, is being processed
# The city: qaanaaq, city id: 3831208, is being processed
# The city: zhezkazgan, city id: 1516589, is being processed
# The city: bluff, city id: 2175403, is being processed
# The city: kapaa, city id: 5848280, is being processed
# The city: amboasary, city id: 1081790, is being processed
# The city: muana, city id: 3394326, is being processed
# The city: pangnirtung, city id: 6096551, is being processed
# The city: yarada, city id: 1252783, is being processed
# The city: hasaki, city id: 2112802, is being processed
# The city: sainte-marie, city id: 6945989, is being processed
# The city: victoria, city id: 1733782, is being processed
# The city: hami, city id: 1529484, is being processed
# The city: ancud, city id: 3899695, is being processed
# The city: college, city id: 5859699, is being processed
# The city: east london, city id: 1006984, is being processed
# The city: muros, city id: 3115824, is being processed
# The city: mahebourg, city id: 934322, is being processed
# The city: ternate, city id: 1682474, is being processed
# The city: saldanha, city id: 2737599, is being processed
# The city: qasigiannguit, city id: 3420768, is being processed
# The city: svetlaya, city id: 2015852, is being processed
# The city: bambanglipuro, city id: 1650434, is being processed
# The city: bethel, city id: 5880568, is being processed
# The city: avarua, city id: 4035715, is being processed
# The city: fredericton, city id: 5957776, is being processed
# Oops, stornoway is not in the API database!
# The city: tiksi, city id: 2015306, is being processed
# The city: samarai, city id: 2132606, is being processed
# The city: vaini, city id: 1273574, is being processed
# The city: belyy yar, city id: 1510377, is being processed
# The city: longyearbyen, city id: 2729907, is being processed
# The city: luena, city id: 3347719, is being processed
# The city: faanui, city id: 4034551, is being processed
# The city: makakilo city, city id: 5850554, is being processed
# The city: pevek, city id: 2122090, is being processed
# The city: kavieng, city id: 2094342, is being processed
# The city: mutoko, city id: 884927, is being processed
# The city: arys, city id: 1526168, is being processed
# The city: arraial do cabo, city id: 3471451, is being processed
# The city: bow island, city id: 5906757, is being processed
# The city: norman wells, city id: 6089245, is being processed
# The city: namatanai, city id: 2090021, is being processed
# The city: chokurdakh, city id: 2126123, is being processed
# The city: saskylakh, city id: 2017155, is being processed
# The city: minab, city id: 123941, is being processed
# The city: ampanihy, city id: 1078553, is being processed
# The city: road town, city id: 3577430, is being processed
# Oops, tsihombe is not in the API database!
# The city: carbonia, city id: 2525362, is being processed
# The city: harnosand, city id: 2707684, is being processed
# Oops, vaitupu is not in the API database!
# The city: jacareacanga, city id: 3397763, is being processed
# The city: hofn, city id: 2630299, is being processed
# The city: aksha, city id: 2028028, is being processed
# The city: oranjemund, city id: 3354071, is being processed
# The city: ippy, city id: 238566, is being processed
# The city: laguna, city id: 4013704, is being processed
# The city: yuzhno-kurilsk, city id: 2119447, is being processed
# The city: pisco, city id: 3932145, is being processed
# The city: wanning, city id: 3220813, is being processed
# The city: castro, city id: 3896218, is being processed
# The city: masiga, city id: 1700686, is being processed
# The city: umm kaddadah, city id: 364933, is being processed
# The city: bundaberg, city id: 2173323, is being processed
# The city: saint george, city id: 262462, is being processed
# The city: tambun, city id: 1734634, is being processed
# The city: kilindoni, city id: 157429, is being processed
# Oops, mys shmidta is not in the API database!
# Oops, korla is not in the API database!
# The city: dryden, city id: 5942913, is being processed
# The city: fare, city id: 4034496, is being processed
# Oops, olafsvik is not in the API database!
# The city: florida, city id: 3558771, is being processed
# The city: ambilobe, city id: 1082243, is being processed
# The city: clyde river, city id: 5924351, is being processed
# The city: ballina, city id: 2966778, is being processed
# The city: flinders, city id: 6255012, is being processed
# The city: lagos, city id: 2332459, is being processed
# Oops, palabuhanratu is not in the API database!
# The city: mandal, city id: 2031533, is being processed
# The city: san juan, city id: 4568138, is being processed
# The city: mar del plata, city id: 3863379, is being processed
# The city: kupang, city id: 2057087, is being processed
# The city: burnie, city id: 2173125, is being processed
# The city: whitecourt, city id: 6180285, is being processed
# The city: lujan, city id: 3863379, is being processed
# Oops, machali is not in the API database!
# The city: kodiak, city id: 4407665, is being processed
# The city: hyderabad, city id: 1269843, is being processed
# The city: dali, city id: 1814093, is being processed
# The city: barrow, city id: 3833859, is being processed
# Oops, ust-kamchatsk is not in the API database!
# The city: caconda, city id: 3351380, is being processed
# The city: berlevag, city id: 780687, is being processed
# The city: katobu, city id: 1640972, is being processed
# Oops, koungou is not in the API database!
# The city: benghazi, city id: 88319, is being processed
# The city: port elizabeth, city id: 4501427, is being processed
# Oops, qabis is not in the API database!
# The city: qaqortoq, city id: 3420846, is being processed
# The city: lompoc, city id: 5367788, is being processed
# Oops, barentsburg is not in the API database!
# The city: acapulco, city id: 3533462, is being processed
# The city: walvis bay, city id: 3359638, is being processed
# The city: roald, city id: 3141667, is being processed
# The city: la huerta, city id: 3995652, is being processed
# The city: san quintin, city id: 1688687, is being processed
# The city: iqaluit, city id: 5983720, is being processed
# The city: rognan, city id: 3141548, is being processed
# The city: maragogi, city id: 3395458, is being processed
# The city: qarqin, city id: 1129516, is being processed
# The city: golden, city id: 5962582, is being processed
# Oops, belushya guba is not in the API database!
# The city: baryatino, city id: 578947, is being processed
# The city: nome, city id: 4732862, is being processed
# The city: uglekamensk, city id: 2014573, is being processed
# The city: sopur, city id: 1255714, is being processed
# Oops, katha is not in the API database!
# The city: ponta do sol, city id: 3453439, is being processed
# The city: san juan bautista, city id: 3437063, is being processed
# The city: hamilton, city id: 5969785, is being processed
# The city: znamenskoye, city id: 1485020, is being processed
# The city: hansot, city id: 1270413, is being processed
# The city: praya, city id: 1630662, is being processed
# The city: martapura, city id: 1636022, is being processed
# The city: sidney, city id: 5677735, is being processed
# The city: vardo, city id: 4372777, is being processed
# The city: georgetown, city id: 3378644, is being processed
# The city: sitka, city id: 4267710, is being processed
# The city: kuryk, city id: 609919, is being processed
# The city: athabasca, city id: 5887916, is being processed
# The city: hay river, city id: 5972762, is being processed
# The city: egvekinot, city id: 4031742, is being processed
# The city: ambon, city id: 3037899, is being processed
# The city: tigre, city id: 3427761, is being processed
# The city: kruisfontein, city id: 986717, is being processed
# The city: pio ix, city id: 3392020, is being processed
# Oops, formoso do araguaia is not in the API database!
# The city: simao, city id: 1794209, is being processed
# The city: ashland, city id: 4282757, is being processed
# Oops, satitoa is not in the API database!
# The city: rocha, city id: 3440777, is being processed
# The city: port victoria, city id: 2063026, is being processed
# The city: upernavik, city id: 3418910, is being processed
# The city: inhambane, city id: 1045114, is being processed
# The city: tres palos, city id: 3533462, is being processed
# The city: kirakira, city id: 2178753, is being processed
# The city: grindavik, city id: 3416888, is being processed
# The city: xining, city id: 1788852, is being processed
# The city: provideniya, city id: 4031574, is being processed
# The city: tazmalt, city id: 2477537, is being processed
# The city: nuevo progreso, city id: 3520271, is being processed
# The city: nanlong, city id: 1799908, is being processed
# The city: kitimat, city id: 5993072, is being processed
# The city: jamestown, city id: 2069194, is being processed
# The city: preston, city id: 2639912, is being processed
# The city: tasiilaq, city id: 3424607, is being processed
# The city: saint-augustin, city id: 3031582, is being processed
# Oops, bengkulu is not in the API database!
# The city: cabo san lucas, city id: 3985710, is being processed
# The city: shimoda, city id: 1852357, is being processed
# The city: mecca, city id: 104515, is being processed
# The city: severo-kurilsk, city id: 2121385, is being processed
# The city: airai, city id: 1651810, is being processed
# The city: pangai, city id: 4032369, is being processed
# The city: ayan, city id: 749747, is being processed
# The city: haines junction, city id: 5969025, is being processed
# The city: isangel, city id: 2136825, is being processed
# The city: mao, city id: 3496831, is being processed
# The city: kaitangata, city id: 2208248, is being processed
# The city: khatanga, city id: 2022572, is being processed
# The city: camacari, city id: 3468031, is being processed
# The city: fort beaufort, city id: 1003953, is being processed
# The city: chapais, city id: 5919850, is being processed
# The city: sawakin, city id: 367544, is being processed
# The city: pinega, city id: 509483, is being processed
# The city: luganville, city id: 2136150, is being processed
# The city: mizdah, city id: 2214827, is being processed
# The city: ust-maya, city id: 2013918, is being processed
# The city: katsuura, city id: 1865309, is being processed
# Oops, bac lieu is not in the API database!
# The city: touros, city id: 3386213, is being processed
# The city: annau, city id: 162199, is being processed
# The city: karasjok, city id: 779350, is being processed
# Oops, attawapiskat is not in the API database!
# The city: sedniv, city id: 694715, is being processed
# The city: skorodnoye, city id: 492351, is being processed
# The city: vredendal, city id: 3359736, is being processed
# The city: palmer, city id: 2067070, is being processed
# The city: beli potok, city id: 792680, is being processed
# The city: cherskiy, city id: 2126199, is being processed
# The city: bambous virieux, city id: 1106677, is being processed
# Oops, sakakah is not in the API database!
# The city: rio gallegos, city id: 3838859, is being processed
# The city: dayong, city id: 1712986, is being processed
# The city: tilichiki, city id: 2120591, is being processed
# The city: cayenne, city id: 3382160, is being processed
# The city: harper, city id: 4696310, is being processed
# The city: merrill, city id: 5572979, is being processed
# The city: nemuro, city id: 2128975, is being processed
# The city: sola, city id: 3137942, is being processed
# The city: kahului, city id: 5847411, is being processed
# The city: leshukonskoye, city id: 535839, is being processed
# The city: strezhevoy, city id: 1490796, is being processed
# The city: niquero, city id: 3545981, is being processed
# The city: jidong, city id: 2036519, is being processed
# The city: zhangjiakou, city id: 2033196, is being processed
# The city: hengyang, city id: 1808370, is being processed
# The city: sioux lookout, city id: 6148373, is being processed
# The city: lahaina, city id: 5849996, is being processed
# The city: mount isa, city id: 2065594, is being processed
# Oops, asau is not in the API database!
# The city: chai nat, city id: 1611416, is being processed
# The city: mount gambier, city id: 2156643, is being processed
# The city: sumbe, city id: 3346015, is being processed
# The city: lagoa, city id: 2267254, is being processed
# The city: nipawin, city id: 6088469, is being processed
# The city: alanya, city id: 324190, is being processed
# The city: kvarkeno, city id: 537541, is being processed
# The city: nova olimpia, city id: 3456137, is being processed
# The city: moerai, city id: 4034188, is being processed
# Oops, paradwip is not in the API database!
# The city: novobelokatay, city id: 519027, is being processed
# The city: tabou, city id: 2281120, is being processed
# The city: atar, city id: 2381334, is being processed
# The city: caravelas, city id: 3466980, is being processed
# The city: flin flon, city id: 5954718, is being processed
# The city: kirkwall, city id: 2645198, is being processed
# The city: gorontalo, city id: 1643837, is being processed
# The city: massakory, city id: 2428228, is being processed
# The city: panjab, city id: 1131162, is being processed
# The city: nurota, city id: 1513087, is being processed
# The city: yar-sale, city id: 1486321, is being processed
# Oops, barbar is not in the API database!
# The city: bilibino, city id: 2126682, is being processed
# The city: hovd, city id: 7626384, is being processed
# The city: mawlaik, city id: 1310120, is being processed
# The city: piacabucu, city id: 3454005, is being processed
# The city: sarangani, city id: 1687186, is being processed
# The city: balaipungut, city id: 1650600, is being processed
# The city: nacala, city id: 1035025, is being processed
# The city: dangriga, city id: 3582228, is being processed
# The city: nuuk, city id: 3421319, is being processed
# Oops, artyk is not in the API database!
# The city: ejido, city id: 3644417, is being processed
# The city: puerto colombia, city id: 3671497, is being processed
# The city: hualmay, city id: 3939761, is being processed
# Oops, sedelnikovo is not in the API database!
# The city: klaksvik, city id: 2618795, is being processed
# The city: amatenango del valle, city id: 3532925, is being processed
# The city: cap malheureux, city id: 934649, is being processed
# The city: reinosa, city id: 3112075, is being processed
# The city: port blair, city id: 1259385, is being processed
# The city: soubre, city id: 2598243, is being processed
# The city: lorengau, city id: 2092164, is being processed
# Oops, tanshui is not in the API database!
# The city: manoel urbano, city id: 3663495, is being processed
# The city: sabha, city id: 2212775, is being processed
# The city: parakou, city id: 2392204, is being processed
# The city: port hardy, city id: 6111862, is being processed
# The city: daru, city id: 2409663, is being processed
# The city: lufilufi, city id: 4035249, is being processed
# The city: aquiles serdan, city id: 4011743, is being processed
# The city: fortuna, city id: 2517679, is being processed
# Oops, tarudant is not in the API database!
# The city: kenai, city id: 5866063, is being processed
# The city: dagana, city id: 2246550, is being processed
# The city: novyy urengoy, city id: 1496511, is being processed
# The city: inirida, city id: 3671450, is being processed
# The city: heihe, city id: 2036973, is being processed
# The city: ketchikan, city id: 5554428, is being processed
# The city: havelock, city id: 4470244, is being processed
# Oops, westpunt is not in the API database!
# The city: yokadouma, city id: 2220853, is being processed
# The city: broken hill, city id: 2173911, is being processed
# Oops, sentyabrskiy is not in the API database!
# The city: lata, city id: 1253628, is being processed
# The city: te anau, city id: 2181625, is being processed
# The city: lebu, city id: 344979, is being processed
# The city: sukhaya buyvola, city id: 486725, is being processed
# The city: aykhal, city id: 2027296, is being processed
# The city: port keats, city id: 2063039, is being processed
# The city: labuhan, city id: 1641899, is being processed
# The city: gondanglegi, city id: 1640660, is being processed
# The city: qianan, city id: 2035410, is being processed
# The city: lavrentiya, city id: 4031637, is being processed
# The city: zubtsov, city id: 462008, is being processed
# The city: nanakuli, city id: 5851349, is being processed
# The city: peniche, city id: 2264923, is being processed
# The city: salvador, city id: 3450554, is being processed
# Oops, sudova vyshnya is not in the API database!
# The city: lasa, city id: 146639, is being processed
# The city: zeya, city id: 2012593, is being processed
# Oops, louisbourg is not in the API database!
# The city: amapa, city id: 3603330, is being processed
# The city: jacksonville, city id: 4160021, is being processed
# The city: la palma, city id: 3687505, is being processed
# The city: suntar, city id: 2015913, is being processed
# The city: yulara, city id: 6355222, is being processed
# The city: constitucion, city id: 4011743, is being processed
# The city: merauke, city id: 2082539, is being processed
# The city: bolshoy lug, city id: 2016764, is being processed
# The city: velagici, city id: 3188329, is being processed
# The city: moron, city id: 3631878, is being processed
# The city: ossora, city id: 2122389, is being processed
# The city: fowa, city id: 2352175, is being processed
# The city: pacific grove, city id: 5380437, is being processed
# The city: naze, city id: 2337542, is being processed
# The city: nueva loja, city id: 3655185, is being processed
# The city: half moon bay, city id: 5354943, is being processed
# The city: sobolevo, city id: 525426, is being processed
# The city: narsaq, city id: 3421719, is being processed
# The city: itororo, city id: 3460542, is being processed
# The city: chimbote, city id: 3698304, is being processed
# The city: mayo, city id: 6068416, is being processed
# The city: tumaco, city id: 3666640, is being processed
# The city: takoradi, city id: 2294915, is being processed
# The city: nhulunbuy, city id: 2064735, is being processed
# The city: sinnamary, city id: 3380290, is being processed
# The city: huaiyuan, city id: 1816440, is being processed
# Oops, malwan is not in the API database!
# The city: pauini, city id: 3662927, is being processed
# The city: ewa beach, city id: 5855051, is being processed
# The city: necochea, city id: 3430443, is being processed
# The city: manica, city id: 882955, is being processed
# The city: visnes, city id: 3131500, is being processed
# The city: slave lake, city id: 6149374, is being processed
# Oops, ngukurr is not in the API database!
# The city: obihiro, city id: 2128815, is being processed
# The city: marawi, city id: 1701054, is being processed
# Oops, nizhneyansk is not in the API database!
# The city: aklavik, city id: 5882953, is being processed
# The city: pishva, city id: 120972, is being processed
# The city: lensk, city id: 2020838, is being processed
# The city: urengoy, city id: 1488414, is being processed
# The city: kununurra, city id: 2068110, is being processed
# The city: yerbogachen, city id: 2012956, is being processed
# Oops, labutta is not in the API database!
# The city: zhuhai, city id: 2052479, is being processed
# The city: portoferraio, city id: 3170094, is being processed
# The city: gat, city id: 2249901, is being processed
# The city: huarmey, city id: 3939168, is being processed
# The city: adrar, city id: 2508813, is being processed
# Oops, saleaula is not in the API database!
# The city: port augusta, city id: 2063056, is being processed
# The city: faya, city id: 110690, is being processed
# The city: nsanje, city id: 924572, is being processed
# The city: san patricio, city id: 3437029, is being processed
# Oops, grand centre is not in the API database!
# The city: kloulklubed, city id: 7671223, is being processed
# The city: tura, city id: 1254046, is being processed
# The city: lobito, city id: 3347939, is being processed
# The city: liverpool, city id: 2644210, is being processed
# The city: baruun-urt, city id: 2032614, is being processed
# The city: hirara, city id: 1862505, is being processed
# The city: kaura namoda, city id: 2334756, is being processed
# The city: dossor, city id: 610023, is being processed
# Oops, lolua is not in the API database!
# The city: winslow, city id: 2633808, is being processed
# The city: hambantota, city id: 1244926, is being processed
# The city: kibala, city id: 2425791, is being processed
# The city: san blas, city id: 3987544, is being processed
# The city: sao desiderio, city id: 3449304, is being processed
# Oops, ayios matthaios is not in the API database!
# The city: dumai, city id: 1645133, is being processed
# The city: alyangula, city id: 2079582, is being processed
# The city: khor, city id: 2022317, is being processed
# The city: oxford, city id: 4081914, is being processed
# The city: kharitonovo, city id: 550574, is being processed
# The city: lixourion, city id: 258175, is being processed
# The city: bandarbeyla, city id: 64814, is being processed
# The city: abu dhabi, city id: 292968, is being processed
# Oops, umzimvubu is not in the API database!
# The city: sterling, city id: 4787534, is being processed
# The city: ormara, city id: 1168700, is being processed
# The city: marmora, city id: 6535469, is being processed
# The city: scottsbluff, city id: 5699404, is being processed
# The city: barraute, city id: 5894033, is being processed
# The city: cedar city, city id: 5536630, is being processed
# The city: brande, city id: 3221042, is being processed
# The city: aksarka, city id: 1512019, is being processed
# The city: manakara, city id: 1061605, is being processed
# The city: kisangani, city id: 212730, is being processed
# The city: nelson bay, city id: 2155562, is being processed
# The city: babynino, city id: 579838, is being processed
# The city: kokopo, city id: 2093685, is being processed
# The city: savalou, city id: 2391895, is being processed
# The city: coquimbo, city id: 3893629, is being processed
# The city: sasovo, city id: 461699, is being processed
# The city: kailua, city id: 5847486, is being processed
# The city: oranjestad, city id: 3577154, is being processed
# The city: garden city, city id: 5118226, is being processed
# The city: magistralnyy, city id: 2020584, is being processed
# The city: bathsheba, city id: 3374083, is being processed
# The city: prince george, city id: 6113365, is being processed
# The city: venado tuerto, city id: 3833062, is being processed
# The city: ust-nera, city id: 2120048, is being processed
# The city: betsiamites, city id: 6945992, is being processed
# The city: nyurba, city id: 2018735, is being processed
# The city: arman, city id: 2127060, is being processed
# The city: itamaraca, city id: 3397963, is being processed
# The city: pak phanang, city id: 1608033, is being processed
# The city: bonavista, city id: 5905393, is being processed
# The city: kuusamo, city id: 649924, is being processed
# Oops, pingzhuang is not in the API database!
# The city: khilok, city id: 2022463, is being processed
# The city: los llanos de aridane, city id: 2514651, is being processed
# The city: painesville, city id: 5166009, is being processed
# The city: lodja, city id: 211647, is being processed
# The city: tateyama, city id: 1849876, is being processed
# The city: kapiri mposhi, city id: 913029, is being processed
# The city: loreto, city id: 3438834, is being processed
# The city: avera, city id: 4231997, is being processed
# The city: waddan, city id: 2209055, is being processed
# The city: laukaa, city id: 648739, is being processed
# The city: naples, city id: 4165565, is being processed
# The city: tecate, city id: 3982266, is being processed
# The city: chiang kham, city id: 1611202, is being processed
# The city: south yarmouth, city id: 4951579, is being processed
# The city: hun, city id: 2790471, is being processed
# The city: fairbanks, city id: 5861897, is being processed
# The city: discovery bay, city id: 3490716, is being processed
# The city: tautira, city id: 4033557, is being processed
# The city: marogong, city id: 1700847, is being processed
# The city: ust-tsilma, city id: 477940, is being processed
# The city: cockburn town, city id: 3576994, is being processed
# The city: belluno, city id: 3182210, is being processed
# The city: visby, city id: 2662689, is being processed
# The city: tezu, city id: 1254709, is being processed
# The city: linqiong, city id: 1803365, is being processed
# The city: port macquarie, city id: 2152659, is being processed
# The city: labuan, city id: 1733782, is being processed
# The city: wilmington, city id: 4145381, is being processed
# The city: oksfjord, city id: 778362, is being processed
# The city: auki, city id: 2339937, is being processed
# The city: antalaha, city id: 1071296, is being processed
# The city: channel-port aux basques, city id: 5919815, is being processed
# The city: shar, city id: 2347266, is being processed
# The city: urucui, city id: 3385658, is being processed
# The city: sorland, city id: 3137469, is being processed
# The city: krasnaya gorbatka, city id: 542776, is being processed
# The city: kuragino, city id: 1501356, is being processed
# The city: kusa, city id: 538442, is being processed
# The city: maniitsoq, city id: 3421982, is being processed
# The city: sayat, city id: 1218436, is being processed
# The city: dimapur, city id: 1272552, is being processed
# The city: husavik, city id: 5961417, is being processed
# The city: verkhnyaya inta, city id: 1487332, is being processed
# The city: khani, city id: 610864, is being processed
# The city: port-gentil, city id: 2396518, is being processed
# The city: margate, city id: 2158744, is being processed
# The city: kralendijk, city id: 3513563, is being processed
# Oops, andevoranto is not in the API database!
# The city: comodoro rivadavia, city id: 3860443, is being processed
# The city: ayagoz, city id: 1525988, is being processed
# The city: kutum, city id: 371745, is being processed
# The city: binzhou, city id: 1816336, is being processed
# Oops, bokspits is not in the API database!
# The city: kaduy, city id: 554535, is being processed
# The city: kushiro, city id: 2129072, is being processed
# The city: guadalupe y calvo, city id: 4005370, is being processed
# The city: batticaloa, city id: 1250161, is being processed
# The city: puri, city id: 1635111, is being processed
# Oops, urdzhar is not in the API database!
# The city: cerritos, city id: 5335663, is being processed
# The city: cheremshan, city id: 569318, is being processed
# The city: yakeshi, city id: 2033536, is being processed
# The city: mehamn, city id: 778707, is being processed
# The city: guerrero negro, city id: 4021858, is being processed
# The city: ola, city id: 2122574, is being processed
# The city: lat yao, city id: 1152377, is being processed
# The city: sao jose da coroa grande, city id: 3388456, is being processed
# The city: padang, city id: 1633419, is being processed
# The city: roma, city id: 6539761, is being processed
# The city: araruama, city id: 3471715, is being processed
# The city: nautla, city id: 3522788, is being processed
# The city: lashio, city id: 1314759, is being processed
# The city: quballat, city id: 2467980, is being processed
# The city: kapuskasing, city id: 5989403, is being processed
# The city: douentza, city id: 2458334, is being processed
# The city: kirkland lake, city id: 5992836, is being processed
# The city: lianzhou, city id: 1803841, is being processed
# The city: alford, city id: 2637762, is being processed
# The city: tymovskoye, city id: 2120334, is being processed
# The city: tual, city id: 1623197, is being processed
# The city: waingapu, city id: 1622318, is being processed
# The city: colon, city id: 5068725, is being processed
# The city: vanavara, city id: 2013727, is being processed
# The city: salina, city id: 4550364, is being processed
# The city: codrington, city id: 2160063, is being processed
# The city: vestmanna, city id: 2610343, is being processed
# The city: lavumisa, city id: 935051, is being processed
# Oops, tumannyy is not in the API database!
# The city: ilebo, city id: 215976, is being processed
# Oops, rungata is not in the API database!
# The city: aguimes, city id: 2522325, is being processed
# The city: majene, city id: 1636806, is being processed
# The city: ahipara, city id: 2194098, is being processed
# The city: langham, city id: 6049403, is being processed
# The city: nambucca heads, city id: 2155858, is being processed
# The city: kathu, city id: 991664, is being processed
# Oops, tempoal is not in the API database!
# The city: newberry, city id: 5003435, is being processed
# The city: japura, city id: 1642773, is being processed
# The city: fort nelson, city id: 5955902, is being processed
# The city: nouadhibou, city id: 2377457, is being processed
# The city: asuncion nochixtlan, city id: 3532656, is being processed
# The city: phangnga, city id: 1151464, is being processed
# The city: vostok, city id: 2013279, is being processed
# The city: sri aman, city id: 1735799, is being processed
# The city: olinda, city id: 3650121, is being processed
# The city: sambava, city id: 1056899, is being processed
# The city: tubuala, city id: 3700393, is being processed
# The city: suratgarh, city id: 1255361, is being processed
# Oops, tuggurt is not in the API database!
# The city: cabinda, city id: 2243271, is being processed
# The city: fuxin, city id: 2037346, is being processed
# The city: lampa, city id: 3885273, is being processed
# The city: praia da vitoria, city id: 3372760, is being processed
# The city: vryburg, city id: 942511, is being processed
# The city: tigil, city id: 2120612, is being processed
# Oops, camana is not in the API database!
# The city: menongue, city id: 3347353, is being processed
# The city: okhotsk, city id: 2122605, is being processed
# The city: huilong, city id: 1795424, is being processed
# The city: vila franca do campo, city id: 3372472, is being processed
# The city: beni suef, city id: 359173, is being processed
# The city: bilma, city id: 2446796, is being processed
# The city: barra do garcas, city id: 3470709, is being processed
# The city: natal, city id: 3394023, is being processed
# The city: ariquemes, city id: 3665199, is being processed
# The city: puerto palomas, city id: 3991350, is being processed
# The city: itoman, city id: 1861280, is being processed
# Oops, jabiru is not in the API database!
# The city: tucuman, city id: 3934608, is being processed
# Oops, kamenskoye is not in the API database!
# The city: moa, city id: 3546791, is being processed
# The city: maraba, city id: 3395503, is being processed
# The city: chitral, city id: 1181065, is being processed
# The city: colquechaca, city id: 3919720, is being processed
# The city: cizre, city id: 318253, is being processed

# %%
#create Dataframe from API responses and populate columns
weather_pd = pd.DataFrame()
weather_pd["City ID"] = city_id
weather_pd["City Name"] = city_namez
weather_pd["Temp"] = temp
weather_pd["Humidity"] = humidity
weather_pd["Cloudiness"] = cloudiness
weather_pd["Wind Speed"] = wind_speed
weather_pd["Latitude"] = latitude
weather_pd["Longitude"] = longitude
weather_pd["Country"] = country
weather_pd["Max Temp"] = max_temp
weather_pd["Date"] = date
weather_pd.head()

#save that shit.
#weather_pd.to_csv("Weather_pd2.csv")
# Out:
#    City ID       City Name   Temp  Humidity  Cloudiness  Wind Speed  Latitude  \
# 0  1848373           Fukue  80.60        74          20       13.87     35.03
# 1  1674199           Yilan  82.40        83          40        6.93     24.75
# 2  3372707  Ribeira Grande  73.40        78          75        8.05     38.52
# 3   145724          Lucapa  64.36        70           0        3.74     -8.42
# 4  2190224        Hastings  54.91        96          80       17.38    -39.64
#
#    Longitude Country  Max Temp        Date
# 0     136.69      JP     80.60  1533675600
# 1     121.75      TW     82.40  1533675600
# 2     -28.70      PT     73.40  1533673800
# 3      20.74      AO     64.36  1533677725
# 4     176.84      NZ     54.91  1533677727

# %%
 # Build a scatter plot for each data type
plt.scatter(weather_pd["Latitude"], weather_pd["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("Max Temperature in World Cities 8/7/18")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("MaxTempInWorldCities2.png")

# Show plot
plt.show()

# %%
 # Build a scatter plot for each data type
plt.scatter(weather_pd["Latitude"], weather_pd["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("Humidity in World Cities 8/7/18")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityInWorldCities2.png")

# Show plot
plt.show()

# %%
 # Build a scatter plot for each data type
plt.scatter(weather_pd["Latitude"], weather_pd["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("Cloudiness in World Cities 8/7/18")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CloudinessInWorldCities2.png")

# Show plot
plt.show()

# %%
 # Build a scatter plot for each data type
plt.scatter(weather_pd["Latitude"], weather_pd["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("Wind Speed in World Cities 8/7/18")
plt.ylabel("Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("WindSpeedInWorldCities2.png")

# Show plot
plt.show()

# %%
len(city_id)
# Out:
# 571

# %%
bins = [0, 20, 40, 60, 80, 100, 120]

# Create the names for the four bins
group_names = ["0-20", "20-40", "40-60", "60-80", "80-100", "100-120"]

# %%
weather_pd["Temp-groups"] = weather_pd["Temp"]
weather_pd["Temp-groups"] = pd.cut(weather_pd["Temp"], bins, labels=group_names)
weather_pd = weather_pd.groupby("Temp-groups")
weather_pd.count()
# Out:
#              City ID  City Name  Temp  Humidity  Cloudiness  Wind Speed  \
# Temp-groups
# 0-20               0          0     0         0           0           0
# 20-40             21         21    21        21          21          21
# 40-60            153        153   153       153         153         153
# 60-80            256        256   256       256         256         256
# 80-100           140        140   140       140         140         140
# 100-120            1          1     1         1           1           1
#
#              Latitude  Longitude  Country  Max Temp  Date
# Temp-groups
# 0-20                0          0        0         0     0
# 20-40              21         21       21        21    21
# 40-60             153        153      153       153   153
# 60-80             256        256      256       256   256
# 80-100            140        140      140       140   140
# 100-120             1          1        1         1     1

# %%
bins = [-60, -40, -20, 0, 20, 40, 60, 80]

# Create the names for the four bins
lat_groups = ["-60", "-40", "-20", "0", "20", "40", "60"]

weather_pd["Lat-Groups"] = weather_pd["Latitude"]
weather_pd["Lat-Groups"] = pd.cut(weather_pd["Latitude"], bins, labels=lat_groups)
weather_pd = weather_pd.groupby("Lat-Groups")
weather_pd["Max Temp"].mean()
# Out:
# Lat-Groups
# -60    43.578750
# -40    55.434603
# -20    73.716882
# 0      79.126966
# 20     81.124220
# 40     67.551473
# 60     51.935000
# Name: Max Temp, dtype: float64
